# %%
import requests
import pandas as pd

# %%
url = "https://mappingpoliceviolence.org/s/MPVDatasetDownload.xlsx"
r = requests.get(url, allow_redirects=True)
open('data/MPVDatasetDownload.xlsx','wb').write(r.content)
# Out:
# 3696293

# %%
mpv_db_pk = pd.read_excel('data/MPVDatasetDownload.xlsx',sheet_name='2013-2020 Police Killings')
mpv_db_pkpd = pd.read_excel('data/MPVDatasetDownload.xlsx',sheet_name='2013-2020 Killings by PD')
mpv_db_pkstate = pd.read_excel('data/MPVDatasetDownload.xlsx',sheet_name='2013-2020 Killings by State')

# %%
mpv_db_pk.head(10)
# Out:
#                      victim_name victim_age victim_gender   victim_race  \
# 0        Name withheld by police         55          Male         White
# 1        Name withheld by police    Unknown          Male  Unknown Race
# 2  Roderick Devonne Merchant Jr.         21          Male  Unknown Race
# 3        Name withheld by police    Unknown          Male  Unknown Race
# 4                  Kody C Waters         31          Male  Unknown Race
# 5                  Steve Newsome         31          Male  Unknown Race
# 6          Kortnee Lashon Warren         23          Male         Black
# 7               Jesse Bonsignore         44          Male  Unknown Race
# 8        Name withheld by police         31          Male  Unknown Race
# 9               Brandon S. Odell         31          Male  Unknown Race
#
#   URL of image of victim Date of Incident (month/day/year)  \
# 0                    NaN                        2021-05-23
# 1                    NaN                        2021-05-23
# 2                    NaN                        2021-05-23
# 3                    NaN                        2021-05-22
# 4                    NaN                        2021-05-22
# 5                    NaN                        2021-05-22
# 6                    NaN                        2021-05-21
# 7                    NaN                        2021-05-20
# 8                    NaN                        2021-05-20
# 9                    NaN                        2021-05-20
#
#               Street Address of Incident               City State  Zipcode  \
# 0                         940 Berger Rd.  Williams Township    PA  18042.0
# 1    Illinois Route 3 and Clarence Drive            Red Bed    IL      NaN
# 2                 2400 Central Park Lane    College Station    TX  77840.0
# 3  West 10 Mile Road and Comstock Avenue    Beaver Township    MI      NaN
# 4                   819 Edwardsville Rd.               Troy    IL  62294.0
# 5                           700 Tony St.               Adel    GA  31620.0
# 6                 420 West Mercer Avenue             Albany    GA  31701.0
# 7                                    NaN         Manorville    NY      NaN
# 8                     2300 Loveridge Rd.          Pittsburg    CA  94565.0
# 9                          15528 Lee Hwy            Bristol    VA  24202.0
#
#    ... Off-Duty Killing?  \
# 0  ...               NaN
# 1  ...               NaN
# 2  ...               NaN
# 3  ...               NaN
# 4  ...               NaN
# 5  ...               NaN
# 6  ...               NaN
# 7  ...               NaN
# 8  ...               NaN
# 9  ...               NaN
#
#   Geography (via Trulia methodology based on zipcode population density: http://jedkolko.com/wp-content/uploads/2015/05/full-ZCTA-urban-suburban-rural-classification.xlsx )  \
# 0                                           Suburban
# 1                                                NaN
# 2                                           Suburban
# 3                                                NaN
# 4                                           Suburban
# 5                                              Rural
# 6                                           Suburban
# 7                                                NaN
# 8                                           Suburban
# 9                                              Rural
#
#   MPV ID Fatal Encounters ID     Encounter Type (DRAFT)  \
# 0   9210                 NaN       Domestic disturbance
# 1   9211                 NaN       Part 1 Violent Crime
# 2   9212                 NaN          Person with a gun
# 3   9213                 NaN       Domestic disturbance
# 4   9214                 NaN       Part 1 Violent Crime
# 5   9215                 NaN  Other Non-Violent Offense
# 6   9106                 NaN       Person with a Weapon
# 7   9107                 NaN               None/Unknown
# 8   9108                 NaN       Person with a Weapon
# 9   9109                 NaN  Other Non-Violent Offense
#
#   Initial Reported Reason for Encounter (DRAFT)  \
# 0                          domestic disturbance
# 1                                      gunshots
# 2                             person with a gun
# 3                          domestic disturbance
# 4                 gunshots/mental health crisis
# 5                                stolen vehicle
# 6                             person with a gun
# 7                             suspicious person
# 8                             person with a gun
# 9                 violation of protective order
#
#   Names of Officers Involved (DRAFT) Race of Officers Involved (DRAFT)  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# 5                                NaN                               NaN
# 6                                NaN                               NaN
# 7                                NaN                               NaN
# 8                                NaN                               NaN
# 9                                NaN                               NaN
#
#   Known Past Shootings of Officer(s) (DRAFT) Call for Service? (DRAFT)
# 0                                        NaN                       Yes
# 1                                        NaN                       Yes
# 2                                        NaN                       Yes
# 3                                        NaN                       Yes
# 4                                        NaN                       Yes
# 5                                        NaN                       Yes
# 6                                        NaN                        No
# 7                                        NaN                       Yes
# 8                                        NaN                       Yes
# 9                                        NaN                       Yes
#
# [10 rows x 35 columns]

# %%
mpv_db_pk = mpv_db_pk.rename(columns={"Victim\'s name": "victim_name", "Victim\'s age": "victim_age","Victim\'s gender": "victim_gender","Victim\'s race": "victim_race"})

# %%
mpv_db_pk.head()
# Out:
#                      victim_name victim_age victim_gender   victim_race  \
# 0        Name withheld by police         55          Male         White
# 1        Name withheld by police    Unknown          Male  Unknown Race
# 2  Roderick Devonne Merchant Jr.         21          Male  Unknown Race
# 3        Name withheld by police    Unknown          Male  Unknown Race
# 4                  Kody C Waters         31          Male  Unknown Race
#
#   URL of image of victim Date of Incident (month/day/year)  \
# 0                    NaN                        2021-05-23
# 1                    NaN                        2021-05-23
# 2                    NaN                        2021-05-23
# 3                    NaN                        2021-05-22
# 4                    NaN                        2021-05-22
#
#               Street Address of Incident               City State  Zipcode  \
# 0                         940 Berger Rd.  Williams Township    PA  18042.0
# 1    Illinois Route 3 and Clarence Drive            Red Bed    IL      NaN
# 2                 2400 Central Park Lane    College Station    TX  77840.0
# 3  West 10 Mile Road and Comstock Avenue    Beaver Township    MI      NaN
# 4                   819 Edwardsville Rd.               Troy    IL  62294.0
#
#    ... Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43  \
# 0  ...         NaN         NaN         NaN         NaN         NaN
# 1  ...         NaN         NaN         NaN         NaN         NaN
# 2  ...         NaN         NaN         NaN         NaN         NaN
# 3  ...         NaN         NaN         NaN         NaN         NaN
# 4  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 44 Unnamed: 45 Unnamed: 46 Unnamed: 47 Unnamed: 48
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 49 columns]

# %%
droplist = [i for i in mpv_db_pk.columns if i.startswith('Unnamed')]
mpv_db_pk.drop(droplist,axis=1,inplace=True)

# %%
mpv_db_pk.head()
# Out:
#                      victim_name victim_age victim_gender   victim_race  \
# 0        Name withheld by police         55          Male         White
# 1        Name withheld by police    Unknown          Male  Unknown Race
# 2  Roderick Devonne Merchant Jr.         21          Male  Unknown Race
# 3        Name withheld by police    Unknown          Male  Unknown Race
# 4                  Kody C Waters         31          Male  Unknown Race
#
#   URL of image of victim Date of Incident (month/day/year)  \
# 0                    NaN                        2021-05-23
# 1                    NaN                        2021-05-23
# 2                    NaN                        2021-05-23
# 3                    NaN                        2021-05-22
# 4                    NaN                        2021-05-22
#
#               Street Address of Incident               City State  Zipcode  \
# 0                         940 Berger Rd.  Williams Township    PA  18042.0
# 1    Illinois Route 3 and Clarence Drive            Red Bed    IL      NaN
# 2                 2400 Central Park Lane    College Station    TX  77840.0
# 3  West 10 Mile Road and Comstock Avenue    Beaver Township    MI      NaN
# 4                   819 Edwardsville Rd.               Troy    IL  62294.0
#
#    ... Off-Duty Killing?  \
# 0  ...               NaN
# 1  ...               NaN
# 2  ...               NaN
# 3  ...               NaN
# 4  ...               NaN
#
#   Geography (via Trulia methodology based on zipcode population density: http://jedkolko.com/wp-content/uploads/2015/05/full-ZCTA-urban-suburban-rural-classification.xlsx )  \
# 0                                           Suburban
# 1                                                NaN
# 2                                           Suburban
# 3                                                NaN
# 4                                           Suburban
#
#   MPV ID Fatal Encounters ID Encounter Type (DRAFT)  \
# 0   9210                 NaN   Domestic disturbance
# 1   9211                 NaN   Part 1 Violent Crime
# 2   9212                 NaN      Person with a gun
# 3   9213                 NaN   Domestic disturbance
# 4   9214                 NaN   Part 1 Violent Crime
#
#   Initial Reported Reason for Encounter (DRAFT)  \
# 0                          domestic disturbance
# 1                                      gunshots
# 2                             person with a gun
# 3                          domestic disturbance
# 4                 gunshots/mental health crisis
#
#   Names of Officers Involved (DRAFT) Race of Officers Involved (DRAFT)  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
#
#   Known Past Shootings of Officer(s) (DRAFT) Call for Service? (DRAFT)
# 0                                        NaN                       Yes
# 1                                        NaN                       Yes
# 2                                        NaN                       Yes
# 3                                        NaN                       Yes
# 4                                        NaN                       Yes
#
# [5 rows x 35 columns]

# %%
mpv_db_pk.to_csv('data/mpv_db_pk.csv',index=False)
mpv_db_pkpd.to_csv('data/mpv_db_pkpd.csv',index=False)
mpv_db_pkstate.to_csv('data/mpv_db_pkstate.csv',index=False)
